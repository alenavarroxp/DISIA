# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.utils import class_weight
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

# Verificar si hay GPU disponible y configurar TensorFlow para usarla
if tf.config.list_physical_devices('GPU'):
    print("\nGPU disponible. Configurando TensorFlow para usar GPU...")
    physical_devices = tf.config.list_physical_devices('GPU')
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
else:
    print("\nNo se detectó GPU. Se usará CPU.")

# Configuración de rutas para Kaggle
TRAIN_CSV_PATH = '/kaggle/input/dataset/labels/train_data.csv'
TRAIN_IMAGE_DIR = '/kaggle/input/dataset/images'
TEST_CSV_PATH = '/kaggle/input/test-all/labels/test_data.csv'
TEST_IMAGE_DIR = '/kaggle/input/test-all/images'

# Configuración del modelo
IMG_SIZE = (256, 256)  # Tamaño al que se redimensionarán las imágenes
BATCH_SIZE = 32
EPOCHS = 50
INIT_LR = 0.0001

# 1. Cargar y verificar los datos de entrenamiento
print("\nCargando datos de entrenamiento...")
train_df = pd.read_csv(TRAIN_CSV_PATH)
print(f"Total de muestras de entrenamiento: {len(train_df)}")

# Verificar que las imágenes de entrenamiento existen
sample_train_image_path = os.path.join(TRAIN_IMAGE_DIR, f"{train_df.iloc[0]['ID']}.jpg")
if not os.path.exists(sample_train_image_path):
    raise FileNotFoundError(f"No se encontró la imagen de entrenamiento en {sample_train_image_path}")

# 2. Cargar y verificar los datos de prueba (si es necesario)
print("\nCargando datos de prueba...")
test_df = pd.read_csv(TEST_CSV_PATH)
print(f"Total de muestras de prueba: {len(test_df)}")

sample_test_image_path = os.path.join(TEST_IMAGE_DIR, f"{test_df.iloc[0]['ID']}.jpg")
if not os.path.exists(sample_test_image_path):
    raise FileNotFoundError(f"No se encontró la imagen de prueba en {sample_test_image_path}")

# 3. Dividir los datos de entrenamiento (estratificado para mantener proporción de clases)
print("\nDividiendo datos de entrenamiento...")
train_df, val_df = train_test_split(
    train_df, 
    test_size=0.2, 
    random_state=42, 
    stratify=train_df[['transitable', 'Inundado']]
)
print(f"Muestras de entrenamiento: {len(train_df)}")
print(f"Muestras de validación: {len(val_df)}")

# 4. Generador de datos optimizado para GPU
class BWImageGenerator(tf.keras.utils.Sequence):
    def __init__(self, df, img_dir, batch_size=32, shuffle=True, augment=False):
        self.df = df.reset_index(drop=True)
        self.img_dir = img_dir
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.augment = augment
        self.on_epoch_end()
        
        # Pre-calcular los pesos para evitar problemas de índice
        self._precompute_sample_weights()
        
        # Configuración de aumento de datos
        self.augmenter = ImageDataGenerator(
            rotation_range=20,
            width_shift_range=0.1,
            height_shift_range=0.1,
            zoom_range=0.1,
            horizontal_flip=True,
            fill_mode='constant',
            cval=0
        )
    
    def _precompute_sample_weights(self):
        # Calcular weights para transitable
        transitable_classes = np.unique(self.df['transitable'])
        transitable_weights = class_weight.compute_class_weight(
            'balanced',
            classes=transitable_classes,
            y=self.df['transitable']
        )
        self.transitable_weights = np.array([transitable_weights[0] if x == 0 else transitable_weights[1] for x in self.df['transitable']])
        
        # Calcular weights para inundado
        inundado_classes = np.unique(self.df['Inundado'])
        inundado_weights = class_weight.compute_class_weight(
            'balanced',
            classes=inundado_classes,
            y=self.df['Inundado']
        )
        self.inundado_weights = np.array([inundado_weights[0] if x == 0 else inundado_weights[1] for x in self.df['Inundado']])
    
    def __len__(self):
        return int(np.ceil(len(self.df) / self.batch_size))
    
    def __getitem__(self, index):
        start_idx = index * self.batch_size
        end_idx = min((index + 1) * self.batch_size, len(self.df))
        batch_indices = self.indices[start_idx:end_idx]
        current_batch_size = len(batch_indices)
        
        # Pre-asignar memoria para mejor rendimiento con GPU
        X = np.empty((current_batch_size, *IMG_SIZE, 1), dtype=np.float32)
        y_transitable = np.empty((current_batch_size, 1), dtype=np.float32)
        y_inundado = np.empty((current_batch_size, 1), dtype=np.float32)
        sw_transitable = np.empty((current_batch_size, 1), dtype=np.float32)
        sw_inundado = np.empty((current_batch_size, 1), dtype=np.float32)
        
        for i, idx in enumerate(batch_indices):
            row = self.df.iloc[idx]
            img_path = os.path.join(self.img_dir, f"{row['ID']}.jpg")
            img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
            
            if img is None:
                raise ValueError(f"No se pudo cargar la imagen: {img_path}")
                
            img = cv2.resize(img, IMG_SIZE)
            img = img.reshape(*IMG_SIZE, 1)
            
            if self.augment:
                img = self.augmenter.random_transform(img)
                
            X[i,] = img / 255.0  # Normalización
            
            y_transitable[i,] = row['transitable']
            y_inundado[i,] = row['Inundado']
            sw_transitable[i,] = self.transitable_weights[idx]
            sw_inundado[i,] = self.inundado_weights[idx]
            
        # Convertir a tensores para mejor compatibilidad con GPU
        X = tf.convert_to_tensor(X, dtype=tf.float32)
        y_transitable = tf.convert_to_tensor(y_transitable, dtype=tf.float32)
        y_inundado = tf.convert_to_tensor(y_inundado, dtype=tf.float32)
        sw_transitable = tf.convert_to_tensor(sw_transitable, dtype=tf.float32)
        sw_inundado = tf.convert_to_tensor(sw_inundado, dtype=tf.float32)
            
        return X, {'transitable': y_transitable, 'inundado': y_inundado}, {'transitable': sw_transitable, 'inundado': sw_inundado}
    
    def on_epoch_end(self):
        self.indices = np.arange(len(self.df))
        if self.shuffle:
            np.random.shuffle(self.indices)

# 5. Arquitectura del modelo optimizada para GPU
def create_model():
    inputs = Input(shape=(*IMG_SIZE, 1), batch_size=BATCH_SIZE)
    
    # Bloques convolucionales optimizados
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.3)(x)
    
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.4)(x)
    
    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = GlobalAveragePooling2D()(x)
    
    # Capas densas
    x = Dense(512, activation='relu')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    
    # Ramas de salida
    transitable_output = Dense(1, activation='sigmoid', name='transitable')(x)
    inundado_output = Dense(1, activation='sigmoid', name='inundado')(x)
    
    model = Model(inputs=inputs, outputs=[transitable_output, inundado_output])
    
    return model

# 6. Compilar modelo para GPU
def compile_model(model):
    model.compile(
        optimizer=Adam(learning_rate=INIT_LR),
        loss={
            'transitable': 'binary_crossentropy',
            'inundado': 'binary_crossentropy'
        },
        loss_weights={
            'transitable': 1.0,
            'inundado': 1.0
        },
        metrics={
            'transitable': ['accuracy', tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')],
            'inundado': ['accuracy', tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall')]
        }
    )
    return model

# 7. Callbacks para Kaggle con GPU
def get_callbacks():
    return [
        tf.keras.callbacks.EarlyStopping(
            patience=15,
            monitor='val_loss',
            restore_best_weights=True,
            min_delta=0.001,
            verbose=1
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor='val_loss',
            factor=0.5,
            patience=5,
            min_lr=1e-7,
            verbose=1
        ),
        tf.keras.callbacks.ModelCheckpoint(
            'best_model.keras',
            save_best_only=True,
            monitor='val_loss',
            mode='min',
            verbose=1
        ),
        tf.keras.callbacks.CSVLogger('training_log.csv'),
        tf.keras.callbacks.TensorBoard(log_dir='./logs')
    ]

# 8. Entrenamiento del modelo con GPU
def train_model():
    # Crear generadores
    train_gen = BWImageGenerator(
        train_df, 
        img_dir=TRAIN_IMAGE_DIR, 
        augment=True,
        shuffle=True,
        batch_size=BATCH_SIZE
    )
    
    val_gen = BWImageGenerator(
        val_df, 
        img_dir=TRAIN_IMAGE_DIR, 
        augment=False,
        shuffle=False,
        batch_size=BATCH_SIZE
    )
    
    # Crear y compilar modelo
    model = create_model()
    model = compile_model(model)
    print("\nResumen del modelo optimizado para GPU:")
    model.summary()
    
    # Entrenamiento
    print("\nIniciando entrenamiento con GPU...")
    history = model.fit(
        train_gen,
        validation_data=val_gen,
        epochs=EPOCHS,
        callbacks=get_callbacks(),
        verbose=1
    )
    
    return model, history

# 9. Evaluación del modelo con datos de prueba
def evaluate_on_test(model):
    test_gen = BWImageGenerator(
        test_df,
        img_dir=TEST_IMAGE_DIR,
        augment=False,
        shuffle=False,
        batch_size=BATCH_SIZE
    )
    
    print("\nEvaluando en conjunto de prueba...")
    results = model.evaluate(test_gen, verbose=1)
    
    print("\n=== Resultados en Prueba ===")
    print(f"Pérdida total: {results[0]:.4f}")
    print(f"Pérdida transitable: {results[1]:.4f}")
    print(f"Pérdida inundado: {results[2]:.4f}")
    print(f"Accuracy transitable: {results[3]:.4f}")
    print(f"Precisión transitable: {results[4]:.4f}")
    print(f"Recall transitable: {results[5]:.4f}")
    print(f"Accuracy inundado: {results[6]:.4f}")
    print(f"Precisión inundado: {results[7]:.4f}")
    print(f"Recall inundado: {results[8]:.4f}")

# 10. Visualización de resultados
def plot_results(history):
    plt.figure(figsize=(18, 12))
    
    # Pérdida
    plt.subplot(2, 2, 1)
    plt.plot(history.history['loss'], label='Entrenamiento')
    plt.plot(history.history['val_loss'], label='Validación')
    plt.title('Evolución de la Pérdida')
    plt.ylabel('Pérdida')
    plt.xlabel('Época')
    plt.legend()
    
    # Accuracy Transitable
    plt.subplot(2, 2, 2)
    plt.plot(history.history['transitable_accuracy'], label='Entrenamiento')
    plt.plot(history.history['val_transitable_accuracy'], label='Validación')
    plt.title('Accuracy - Transitable')
    plt.ylabel('Accuracy')
    plt.xlabel('Época')
    plt.legend()
    
    # Accuracy Inundado
    plt.subplot(2, 2, 3)
    plt.plot(history.history['inundado_accuracy'], label='Entrenamiento')
    plt.plot(history.history['val_inundado_accuracy'], label='Validación')
    plt.title('Accuracy - Inundado')
    plt.ylabel('Accuracy')
    plt.xlabel('Época')
    plt.legend()
    
    # Pérdida por tarea
    plt.subplot(2, 2, 4)
    plt.plot(history.history['transitable_loss'], label='Transitable (Entren.)')
    plt.plot(history.history['val_transitable_loss'], label='Transitable (Val.)')
    plt.plot(history.history['inundado_loss'], label='Inundado (Entren.)')
    plt.plot(history.history['val_inundado_loss'], label='Inundado (Val.)')
    plt.title('Pérdida por Tarea')
    plt.ylabel('Pérdida')
    plt.xlabel('Época')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

# 11. Ejecución principal
if __name__ == "__main__":
    print("\n=== Configuración Inicial ===")
    print(f"TensorFlow está usando GPU: {len(tf.config.list_physical_devices('GPU')) > 0}")
    print(f"Ruta imágenes entrenamiento: {TRAIN_IMAGE_DIR}")
    print(f"Ruta imágenes prueba: {TEST_IMAGE_DIR}")
    
    try:
        # Entrenar modelo
        trained_model, training_history = train_model()
        
        # Evaluar en validación
        val_gen = BWImageGenerator(val_df, img_dir=TRAIN_IMAGE_DIR, shuffle=False, batch_size=BATCH_SIZE)
        print("\nEvaluando en conjunto de validación...")
        trained_model.evaluate(val_gen, verbose=1)
        
        # Evaluar en prueba
        evaluate_on_test(trained_model)
        
        # Visualizar resultados
        plot_results(training_history)
        
        # Guardar modelo final
        trained_model.save('final_model.keras')
        print("\nModelo final guardado como 'final_model.keras'")
        
    except Exception as e:
        print(f"\nError durante la ejecución: {e}")
        raise
# Out:
# GPU disponible. Configurando TensorFlow para usar GPU...
#
# Cargando datos de entrenamiento...
# Total de muestras de entrenamiento: 252
#
# Cargando datos de prueba...
# Total de muestras de prueba: 7
#
# Dividiendo datos de entrenamiento...
# Muestras de entrenamiento: 201
# Muestras de validación: 51
#
# === Configuración Inicial ===
# TensorFlow está usando GPU: True
# Ruta imágenes entrenamiento: /kaggle/input/dataset/images
# Ruta imágenes prueba: /kaggle/input/test-all/images
#
# Resumen del modelo optimizado para GPU:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (32, 256, 256, 1)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (32, 256, 256, 64)     │            640 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (32, 256, 256, 64)     │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (32, 128, 128, 64)     │              0 │ batch_normalization[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (32, 128, 128, 64)     │              0 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (32, 128, 128, 128)    │         73,856 │ dropout[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (32, 128, 128, 128)    │            512 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (32, 64, 64, 128)      │              0 │ batch_normalization_1… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_1 (Dropout)       │ (32, 64, 64, 128)      │              0 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (32, 64, 64, 256)      │        295,168 │ dropout_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (32, 64, 64, 256)      │          1,024 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (32, 256)              │              0 │ batch_normalization_2… │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (32, 512)              │        131,584 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (32, 512)              │          2,048 │ dense[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_2 (Dropout)       │ (32, 512)              │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ transitable (Dense)       │ (32, 1)                │            513 │ dropout_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ inundado (Dense)          │ (32, 1)                │            513 │ dropout_2[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 506,114 (1.93 MB)
#  Trainable params: 504,194 (1.92 MB)
#  Non-trainable params: 1,920 (7.50 KB)
# Iniciando entrenamiento con GPU...
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 935ms/step - inundado_accuracy: 0.5098 - inundado_loss: 0.8555 - inundado_precision: 0.4076 - inundado_recall: 0.4924 - loss: 1.8940 - transitable_accuracy: 0.5085 - transitable_loss: 0.9998 - transitable_precision: 0.4253 - transitable_recall: 0.4798
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1: val_loss improved from inf to 1.38636, saving model to best_model.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - inundado_accuracy: 0.5120 - inundado_loss: 0.8569 - inundado_precision: 0.4115 - inundado_recall: 0.4956 - loss: 1.8917 - transitable_accuracy: 0.5096 - transitable_loss: 0.9947 - transitable_precision: 0.4260 - transitable_recall: 0.4861 - val_inundado_accuracy: 0.5882 - val_inundado_loss: 0.6939 - val_inundado_precision: 0.0000e+00 - val_inundado_recall: 0.0000e+00 - val_loss: 1.3864 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.6994 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 2/50
# 6/7 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - inundado_accuracy: 0.5664 - inundado_loss: 0.6818 - inundado_precision: 0.4885 - inundado_recall: 0.5546 - loss: 1.4436 - transitable_accuracy: 0.5551 - transitable_loss: 0.7619 - transitable_precision: 0.4786 - transitable_recall: 0.6075
# Epoch 2: val_loss improved from 1.38636 to 1.38632, saving model to best_model.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - inundado_accuracy: 0.5641 - inundado_loss: 0.6841 - inundado_precision: 0.4836 - inundado_recall: 0.5515 - loss: 1.4463 - transitable_accuracy: 0.5569 - transitable_loss: 0.7646 - transitable_precision: 0.4778 - transitable_recall: 0.6002 - val_inundado_accuracy: 0.5882 - val_inundado_loss: 0.6937 - val_inundado_precision: 0.0000e+00 - val_inundado_recall: 0.0000e+00 - val_loss: 1.3863 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.7006 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - inundado_accuracy: 0.5278 - inundado_loss: 0.7222 - inundado_precision: 0.3940 - inundado_recall: 0.4622 - loss: 1.6793 - transitable_accuracy: 0.4417 - transitable_loss: 0.9620 - transitable_precision: 0.3959 - transitable_recall: 0.4914
# Epoch 3: val_loss did not improve from 1.38632
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step - inundado_accuracy: 0.5265 - inundado_loss: 0.7266 - inundado_precision: 0.3975 - inundado_recall: 0.4616 - loss: 1.6739 - transitable_accuracy: 0.4474 - transitable_loss: 0.9523 - transitable_precision: 0.3969 - transitable_recall: 0.4933 - val_inundado_accuracy: 0.5882 - val_inundado_loss: 0.6936 - val_inundado_precision: 0.0000e+00 - val_inundado_recall: 0.0000e+00 - val_loss: 1.3866 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.7019 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - inundado_accuracy: 0.5196 - inundado_loss: 0.6772 - inundado_precision: 0.4396 - inundado_recall: 0.4771 - loss: 1.3892 - transitable_accuracy: 0.4564 - transitable_loss: 0.6764 - transitable_precision: 0.4437 - transitable_recall: 0.5288
# Epoch 4: val_loss did not improve from 1.38632
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - inundado_accuracy: 0.5175 - inundado_loss: 0.6791 - inundado_precision: 0.4357 - inundado_recall: 0.4747 - loss: 1.3934 - transitable_accuracy: 0.4627 - transitable_loss: 0.6799 - transitable_precision: 0.4411 - transitable_recall: 0.5290 - val_inundado_accuracy: 0.5882 - val_inundado_loss: 0.6936 - val_inundado_precision: 0.0000e+00 - val_inundado_recall: 0.0000e+00 - val_loss: 1.3863 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.7016 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - inundado_accuracy: 0.4942 - inundado_loss: 0.6998 - inundado_precision: 0.3800 - inundado_recall: 0.4275 - loss: 1.4207 - transitable_accuracy: 0.4916 - transitable_loss: 0.6810 - transitable_precision: 0.3784 - transitable_recall: 0.5822
# Epoch 5: val_loss improved from 1.38632 to 1.38599, saving model to best_model.keras
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - inundado_accuracy: 0.4908 - inundado_loss: 0.7008 - inundado_precision: 0.3787 - inundado_recall: 0.4253 - loss: 1.4314 - transitable_accuracy: 0.4942 - transitable_loss: 0.6919 - transitable_precision: 0.3856 - transitable_recall: 0.5862 - val_inundado_accuracy: 0.5882 - val_inundado_loss: 0.6935 - val_inundado_precision: 0.0000e+00 - val_inundado_recall: 0.0000e+00 - val_loss: 1.3860 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.7011 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - inundado_accuracy: 0.4035 - inundado_loss: 0.5846 - inundado_precision: 0.3623 - inundado_recall: 0.3518 - loss: 1.3460 - transitable_accuracy: 0.4959 - transitable_loss: 0.7009 - transitable_precision: 0.4147 - transitable_recall: 0.5210
# Epoch 6: val_loss did not improve from 1.38599
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - inundado_accuracy: 0.4103 - inundado_loss: 0.5904 - inundado_precision: 0.3614 - inundado_recall: 0.3560 - loss: 1.3481 - transitable_accuracy: 0.4992 - transitable_loss: 0.6972 - transitable_precision: 0.4173 - transitable_recall: 0.5222 - val_inundado_accuracy: 0.5882 - val_inundado_loss: 0.6935 - val_inundado_precision: 0.0000e+00 - val_inundado_recall: 0.0000e+00 - val_loss: 1.3860 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.7011 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - inundado_accuracy: 0.4991 - inundado_loss: 0.6495 - inundado_precision: 0.4056 - inundado_recall: 0.5055 - loss: 1.3286 - transitable_accuracy: 0.5695 - transitable_loss: 0.7326 - transitable_precision: 0.5643 - transitable_recall: 0.5914
# Epoch 7: val_loss did not improve from 1.38599
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - inundado_accuracy: 0.5045 - inundado_loss: 0.6508 - inundado_precision: 0.4113 - inundado_recall: 0.5055 - loss: 1.3238 - transitable_accuracy: 0.5648 - transitable_loss: 0.7265 - transitable_precision: 0.5499 - transitable_recall: 0.5897 - val_inundado_accuracy: 0.4902 - val_inundado_loss: 0.6928 - val_inundado_precision: 0.4359 - val_inundado_recall: 0.8095 - val_loss: 1.3874 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.7047 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 8/50
# 6/7 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - inundado_accuracy: 0.5126 - inundado_loss: 0.6103 - inundado_precision: 0.3981 - inundado_recall: 0.4658 - loss: 1.3040 - transitable_accuracy: 0.4485 - transitable_loss: 0.6937 - transitable_precision: 0.3978 - transitable_recall: 0.6076
# Epoch 8: val_loss did not improve from 1.38599
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step - inundado_accuracy: 0.5063 - inundado_loss: 0.6033 - inundado_precision: 0.3958 - inundado_recall: 0.4548 - loss: 1.2879 - transitable_accuracy: 0.4595 - transitable_loss: 0.6801 - transitable_precision: 0.4034 - transitable_recall: 0.6063 - val_inundado_accuracy: 0.4510 - val_inundado_loss: 0.6926 - val_inundado_precision: 0.4255 - val_inundado_recall: 0.9524 - val_loss: 1.3881 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.7061 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - inundado_accuracy: 0.5407 - inundado_loss: 0.5410 - inundado_precision: 0.4176 - inundado_recall: 0.5317 - loss: 1.2739 - transitable_accuracy: 0.5280 - transitable_loss: 0.7437 - transitable_precision: 0.4176 - transitable_recall: 0.5648
# Epoch 9: val_loss did not improve from 1.38599
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - inundado_accuracy: 0.5390 - inundado_loss: 0.5432 - inundado_precision: 0.4205 - inundado_recall: 0.5330 - loss: 1.2720 - transitable_accuracy: 0.5273 - transitable_loss: 0.7401 - transitable_precision: 0.4202 - transitable_recall: 0.5635 - val_inundado_accuracy: 0.4118 - val_inundado_loss: 0.6921 - val_inundado_precision: 0.4118 - val_inundado_recall: 1.0000 - val_loss: 1.3874 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.7058 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - inundado_accuracy: 0.4611 - inundado_loss: 0.5919 - inundado_precision: 0.3666 - inundado_recall: 0.4348 - loss: 1.2776 - transitable_accuracy: 0.4744 - transitable_loss: 0.6800 - transitable_precision: 0.4210 - transitable_recall: 0.5302
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
#
# Epoch 10: val_loss did not improve from 1.38599
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - inundado_accuracy: 0.4663 - inundado_loss: 0.5958 - inundado_precision: 0.3723 - inundado_recall: 0.4407 - loss: 1.2824 - transitable_accuracy: 0.4735 - transitable_loss: 0.6793 - transitable_precision: 0.4173 - transitable_recall: 0.5287 - val_inundado_accuracy: 0.4118 - val_inundado_loss: 0.6919 - val_inundado_precision: 0.4118 - val_inundado_recall: 1.0000 - val_loss: 1.3877 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.7064 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - inundado_accuracy: 0.5343 - inundado_loss: 0.5127 - inundado_precision: 0.4596 - inundado_recall: 0.6297 - loss: 1.0864 - transitable_accuracy: 0.4355 - transitable_loss: 0.5731 - transitable_precision: 0.3609 - transitable_recall: 0.5086
# Epoch 11: val_loss did not improve from 1.38599
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step - inundado_accuracy: 0.5341 - inundado_loss: 0.5146 - inundado_precision: 0.4581 - inundado_recall: 0.6218 - loss: 1.0928 - transitable_accuracy: 0.4402 - transitable_loss: 0.5773 - transitable_precision: 0.3656 - transitable_recall: 0.5128 - val_inundado_accuracy: 0.4118 - val_inundado_loss: 0.6919 - val_inundado_precision: 0.4118 - val_inundado_recall: 1.0000 - val_loss: 1.3886 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.7076 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - inundado_accuracy: 0.4913 - inundado_loss: 0.5124 - inundado_precision: 0.4239 - inundado_recall: 0.4518 - loss: 1.0836 - transitable_accuracy: 0.5090 - transitable_loss: 0.5911 - transitable_precision: 0.3659 - transitable_recall: 0.4759
# Epoch 12: val_loss did not improve from 1.38599
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - inundado_accuracy: 0.4934 - inundado_loss: 0.5177 - inundado_precision: 0.4236 - inundado_recall: 0.4601 - loss: 1.0895 - transitable_accuracy: 0.5094 - transitable_loss: 0.5940 - transitable_precision: 0.3732 - transitable_recall: 0.4797 - val_inundado_accuracy: 0.4118 - val_inundado_loss: 0.6920 - val_inundado_precision: 0.4118 - val_inundado_recall: 1.0000 - val_loss: 1.3880 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.7068 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - inundado_accuracy: 0.5269 - inundado_loss: 0.4638 - inundado_precision: 0.4615 - inundado_recall: 0.4754 - loss: 1.0844 - transitable_accuracy: 0.4823 - transitable_loss: 0.6080 - transitable_precision: 0.3890 - transitable_recall: 0.4917
# Epoch 13: val_loss did not improve from 1.38599
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - inundado_accuracy: 0.5220 - inundado_loss: 0.4686 - inundado_precision: 0.4525 - inundado_recall: 0.4687 - loss: 1.0907 - transitable_accuracy: 0.4811 - transitable_loss: 0.6073 - transitable_precision: 0.3894 - transitable_recall: 0.4935 - val_inundado_accuracy: 0.4118 - val_inundado_loss: 0.6921 - val_inundado_precision: 0.4118 - val_inundado_recall: 1.0000 - val_loss: 1.3884 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.7073 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - inundado_accuracy: 0.4850 - inundado_loss: 0.5939 - inundado_precision: 0.3588 - inundado_recall: 0.4506 - loss: 1.2776 - transitable_accuracy: 0.5294 - transitable_loss: 0.7341 - transitable_precision: 0.3848 - transitable_recall: 0.5617
# Epoch 14: val_loss did not improve from 1.38599
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step - inundado_accuracy: 0.4841 - inundado_loss: 0.5907 - inundado_precision: 0.3624 - inundado_recall: 0.4515 - loss: 1.2669 - transitable_accuracy: 0.5260 - transitable_loss: 0.7249 - transitable_precision: 0.3896 - transitable_recall: 0.5623 - val_inundado_accuracy: 0.4118 - val_inundado_loss: 0.6941 - val_inundado_precision: 0.4118 - val_inundado_recall: 1.0000 - val_loss: 1.3940 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.7122 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - inundado_accuracy: 0.4875 - inundado_loss: 0.5989 - inundado_precision: 0.3663 - inundado_recall: 0.4968 - loss: 1.2033 - transitable_accuracy: 0.4466 - transitable_loss: 0.6434 - transitable_precision: 0.3598 - transitable_recall: 0.4316
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
#
# Epoch 15: val_loss did not improve from 1.38599
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - inundado_accuracy: 0.4900 - inundado_loss: 0.6099 - inundado_precision: 0.3734 - inundado_recall: 0.5009 - loss: 1.2136 - transitable_accuracy: 0.4504 - transitable_loss: 0.6434 - transitable_precision: 0.3641 - transitable_recall: 0.4394 - val_inundado_accuracy: 0.4118 - val_inundado_loss: 0.7014 - val_inundado_precision: 0.4118 - val_inundado_recall: 1.0000 - val_loss: 1.3993 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.7091 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 5.0000e-05
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - inundado_accuracy: 0.5503 - inundado_loss: 0.4579 - inundado_precision: 0.5034 - inundado_recall: 0.5140 - loss: 1.0909 - transitable_accuracy: 0.5305 - transitable_loss: 0.6325 - transitable_precision: 0.4705 - transitable_recall: 0.5519
# Epoch 16: val_loss did not improve from 1.38599
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - inundado_accuracy: 0.5449 - inundado_loss: 0.4547 - inundado_precision: 0.4923 - inundado_recall: 0.5084 - loss: 1.0829 - transitable_accuracy: 0.5282 - transitable_loss: 0.6282 - transitable_precision: 0.4659 - transitable_recall: 0.5567 - val_inundado_accuracy: 0.4118 - val_inundado_loss: 0.7110 - val_inundado_precision: 0.4118 - val_inundado_recall: 1.0000 - val_loss: 1.4090 - val_transitable_accuracy: 0.5882 - val_transitable_loss: 0.7094 - val_transitable_precision: 0.0000e+00 - val_transitable_recall: 0.0000e+00 - learning_rate: 2.5000e-05
# Epoch 16: early stopping
# Restoring model weights from the end of the best epoch: 1.
#
# Evaluando en conjunto de validación...
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - inundado_accuracy: 0.6562 - inundado_loss: 0.6920 - inundado_precision: 0.0000e+00 - inundado_recall: 0.0000e+00 - loss: 1.3661 - transitable_accuracy: 0.5938 - transitable_loss: 0.6742 - transitable_precision: 0.0000e+00 - transitable_recall: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - inundado_accuracy: 0.6109 - inundado_loss: 0.6932 - inundado_precision: 0.0000e+00 - inundado_recall: 0.0000e+00 - loss: 1.3796 - transitable_accuracy: 0.5901 - transitable_loss: 0.6910 - transitable_precision: 0.0000e+00 - transitable_recall: 0.0000e+00
#
# Evaluando en conjunto de prueba...
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - inundado_accuracy: 0.5714 - inundado_loss: 0.6932 - inundado_precision: 0.0000e+00 - inundado_recall: 0.0000e+00 - loss: 1.3865 - transitable_accuracy: 0.5714 - transitable_loss: 0.6933 - transitable_precision: 0.0000e+00 - transitable_recall: 0.0000e+00
#
# === Resultados en Prueba ===
# Pérdida total: 1.3865
# Pérdida transitable: 0.6933
# Pérdida inundado: 0.6932
# Accuracy transitable: 0.5714
# Precisión transitable: 0.0000
# Recall transitable: 0.0000
# Accuracy inundado: 0.5714
# Precisión inundado: 0.0000
# Recall inundado: 0.0000
# Modelo final guardado como 'final_model.keras'
